# %%
import pandas as pd
import cv2 
import matplotlib.pyplot as plt
#from sklearn.datasets import fetch_mldata
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import fetch_openml

# %%
mnist=fetch_openml('mnist_784')

# %%
a=mnist.data
b=mnist.target

# %%
a.shape
# Out:
# (70000, 784)

# %%
b.shape
a[5].ndim
# Out:
# 1

# %%
plt.imshow(a[0].reshape(28,28))
plt.show()

# %%
b[0]
# Out:
# '5'

# %%
plt.imshow(a[1].reshape(28,28))
plt.show()

# %%
b[1]
# Out:
# '0'

# %%
from sklearn.decomposition import PCA

# %%
algo=PCA(0.80)

# %%
lower_dim_data=algo.fit_transform(a)

# %%
algo.n_components_
# Out:
# 43

# %%
lower_dim_data.shape
# Out:
# (70000, 43)

# %%
algo1=PCA(n_components=154)

# %%
b=algo1.fit_transform(a)

# %%
sum(algo1.explained_variance_ratio_)
# Out:
# 0.9499113091717228

# %%
orignal_data=algo.inverse_transform(lower_dim_data)

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(a[20].reshape(28,28))
plt.show()
plt.subplot(1,2,1)
plt.imshow(orignal_data[20].reshape(28,28))
plt.show()
